# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavana1904/ProgrammingAssignment2/blob/master/decisiontree1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![sparks.PNG](data:image/png;base64,...)

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
import pandas as pd

# %%
dataset=pd.read_csv("Iris.csv")
col_names = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
x=dataset[col_names]
y=dataset.Species

# %%
print(x)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
print(y)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
print(X_train.head)
# Out:
# <bound method NDFrame.head of      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 60             5.0           2.0            3.5           1.0
# 116            6.5           3.0            5.5           1.8
# 144            6.7           3.3            5.7           2.5
# 119            6.0           2.2            5.0           1.5
# 108            6.7           2.5            5.8           1.8
# ..             ...           ...            ...           ...
# 9              4.9           3.1            1.5           0.1
# 103            6.3           2.9            5.6           1.8
# 67             5.8           2.7            4.1           1.0
# 117            7.7           3.8            6.7           2.2
# 47             4.6           3.2            1.4           0.2
#
# [105 rows x 4 columns]>

# %%
print(y_test)
# Out:
# 114     Iris-virginica
# 62     Iris-versicolor
# 33         Iris-setosa
# 107     Iris-virginica
# 7          Iris-setosa
# 100     Iris-virginica
# 40         Iris-setosa
# 86     Iris-versicolor
# 76     Iris-versicolor
# 71     Iris-versicolor
# 134     Iris-virginica
# 51     Iris-versicolor
# 73     Iris-versicolor
# 54     Iris-versicolor
# 63     Iris-versicolor
# 37         Iris-setosa
# 78     Iris-versicolor
# 90     Iris-versicolor
# 45         Iris-setosa
# 16         Iris-setosa
# 121     Iris-virginica
# 66     Iris-versicolor
# 24         Iris-setosa
# 8          Iris-setosa
# 126     Iris-virginica
# 22         Iris-setosa
# 44         Iris-setosa
# 97     Iris-versicolor
# 93     Iris-versicolor
# 26         Iris-setosa
# 137     Iris-virginica
# 84     Iris-versicolor
# 27         Iris-setosa
# 127     Iris-virginica
# 132     Iris-virginica
# 59     Iris-versicolor
# 18         Iris-setosa
# 83     Iris-versicolor
# 61     Iris-versicolor
# 92     Iris-versicolor
# ...

# %%
classifier = DecisionTreeClassifier()
classifier= classifier.fit(X_train,y_train)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus


dot_data = StringIO()
export_graphviz(classifier, out_file=dot_data, feature_names=col_names,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9777777777777777

# %%
Xnew = [[1.79415228, 2.1,4.6,3.4]]
y_new=classifier.predict(Xnew)
print(y_new)
# Out:
# ['Iris-virginica']
